# %%
import json
import geocoder
with open("static/cities10k.json") as json_file:
        json_data = json.load(json_file)

# %%
for i in range(1000):
    g = geocoder.osm(json_data[i]["location"], method='reverse')
    json_data[i]['country code'] = g.json['country_code']

json_data
# Out:
# [{'location': [28.666666666, 77.216666666],
#   'name': 'Delhi',
#   'population': 26495000,
#   'country code': 'in'},
#  {'location': [31.166666666, 121.466666666],
#   'name': 'Shanghai',
#   'population': 24870895,
#   'country code': 'cn'},
#  {'location': [39.90403, 116.407526],
#   'name': 'Beijing',
#   'population': 21893095,
#   'country code': 'cn'},
#  {'location': [30.66, 104.063333333],
#   'name': 'Chengdu',
#   'population': 20937757,
#   'country code': 'cn'},
#  {'location': [23.13, 113.26],
#   'name': 'Guangzhou',
#   'population': 18676605,
#   'country code': 'cn'},
#  {'location': [22.535, 114.054],
#   'name': 'Shenzhen',
#   'population': 17494398,
#   'country code': 'cn'},
#  {'location': [23.728888888, 90.394444444],
#   'name': 'Dhaka',
#   'population': 16800000,
#   'country code': 'bd'},
#  {'location': [41.01, 28.960277777],
#   'name': 'Istanbul',
#   'population': 15462452,
#   'country code': 'tr'},
#  {'location': [19.075833333, 72.8775],
# ...

# %%
for i in json_data[1000:2000]:
    g = geocoder.osm(i["location"], method='reverse')
    i['country code'] = g.json['country_code']

json_data[1999:2001]
# Out:
# [{'location': [51.616666666, -3.95],
#   'name': 'Swansea',
#   'population': 245508,
#   'country code': 'gb'},
#  {'location': [43.366666666, -8.383333333],
#   'name': 'A Coruña',
#   'population': 245468}]

# %%
for i in json_data[2000:3000]:
    g = geocoder.osm(i["location"], method='reverse')
    i['country code'] = g.json['country_code']

json_data[2999:3001]
# Out:
# [{'location': [29.676111111, -95.173888888],
#   'name': 'Pasadena',
#   'population': 151950,
#   'country code': 'us'},
#  {'location': [-1.717777777, -48.882777777],
#   'name': 'Abaetetuba',
#   'population': 151934}]

# %%
for i in json_data[3000:4000]:
    g = geocoder.osm(i["location"], method='reverse')
    i['country code'] = g.json['country_code']

# %%
for i in json_data[4000:5000]:
    g = geocoder.osm(i["location"], method='reverse')
    i['country code'] = g.json['country_code']

# %%
for i in json_data[5000:6000]:
    g = geocoder.osm(i["location"], method='reverse')
    i['country code'] = g.json['country_code']

# %%
for i in json_data[6000:7000]:
    g = geocoder.osm(i["location"], method='reverse')
    i['country code'] = g.json['country_code']

# %%
#json_data[7160] is the last entry I managed to query
#this is for writing to citiesFinal.json
json_data2 = json_data[:7160]
with open('static/citiesFinal.json', 'w') as fout:
    json.dump(json_data2, fout)

# %%
with open("static/citiesFinal.json") as json_file:
        city_data = json.load(json_file)

# %%
countryDict = {"ar":"south america",
"bo":"south america",
"br":"south america",
"cl":"south america",
